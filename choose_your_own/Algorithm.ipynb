# %%
# %matplotlib inline
# %run your_algorithm.py
# Out:
# ===> GaussianNB
# number of features in train= 2
# training time: 0.001 s
# predict time: 0.0 s
# # of 1's(count_nonzero)= 175
# # of 1's(Counter)= Counter({1.0: 175, 0.0: 75})
# len(pred)= 250  len(labes_test)= 250
# accuracy_score: 0.884
#
# ===> SVC
# number of features in train= 2
# training time: 0.017 s
# predict time: 0.001 s
# # of 1's(count_nonzero)= 163
# # of 1's(Counter)= Counter({1.0: 163, 0.0: 87})
# len(pred)= 250  len(labes_test)= 250
# accuracy_score: 0.932
#
# ===> DecisionTreeClassifier
# number of features in train= 2
# training time: 0.001 s
# predict time: 0.0 s
# # of 1's(count_nonzero)= 180
# # of 1's(Counter)= Counter({1.0: 180, 0.0: 70})
# len(pred)= 250  len(labes_test)= 250
# accuracy_score: 0.912
#
# ===> KNeighborsClassifier
# number of features in train= 2
# training time: 0.001 s
# predict time: 0.001 s
# # of 1's(count_nonzero)= 159
# # of 1's(Counter)= Counter({1.0: 159, 0.0: 91})
# len(pred)= 250  len(labes_test)= 250
# accuracy_score: 0.94
# A
# ...
